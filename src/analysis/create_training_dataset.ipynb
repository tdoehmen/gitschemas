# %% [markdown]
# # Create Training Dataset

# %%
# load metadata
import json
with open('../../data/metadata_postgres_with_licenses_deduplicated.json', 'r') as f:
    metadata = json.load(f)

# %%
# create training data
import pandas as pd
only_open_licenses = False
open_licenses = ["mit", "apache-2.0"]
columns = ["dataset", "table_name_a", "table_name_b", "columns_a", "columns_b", "primary_keys_a", "primary_keys_b", "key_a", "key_b"]
rows = []
for dataset in metadata.keys():
    if only_open_licenses and metadata[dataset]["INFO"]["license"] not in open_licenses:
        continue
    for table_name_a in metadata[dataset]["TABLES"].keys():
        columns_a = [col[0] for col in metadata[dataset]["TABLES"][table_name_a]["COLUMNS"]]
        for fks in metadata[dataset]["TABLES"][table_name_a]["FOREIGN_KEYS"]:
            keys_a = fks["FOREIGN_KEY"]
            keys_b = fks["REFERENCE_COLUMN"]
            # skip composite keys
            if len(keys_a) != 1 or len(keys_b) != 1:
                continue
            key_a = keys_a[0]
            key_b = keys_b[0]
            table_name_b = fks["REFERENCE_TABLE"]
            primary_keys_a = metadata[dataset]["TABLES"][table_name_a]["PRIMARY_KEYS"]
            columns_b = []
            primary_keys_b = []
            if table_name_b in metadata[dataset]["TABLES"]:
                columns_b = [col[0] for col in metadata[dataset]["TABLES"][table_name_b]["COLUMNS"]]
                primary_keys_b = metadata[dataset]["TABLES"][table_name_b]["PRIMARY_KEYS"]
                # skip composite keys
                if len(primary_keys_a) > 1 or len(primary_keys_b) > 1:
                    continue

            primary_key_a = primary_keys_a[0] if len(primary_keys_a) != 0 else ""
            primary_key_b = primary_keys_b[0] if len(primary_keys_b) != 0 else ""
            row = [dataset, table_name_a, table_name_b, columns_a, columns_b, primary_key_a, primary_key_b, key_a, key_b]
            rows.append(row)
df = pd.DataFrame(rows, columns=columns)

# %%
# save training data
df.to_csv("../../data/fk_detection_dataset_deduplicated.csv",index=False)
df.to_parquet("../../data/fk_detection_dataset_deduplicated.parquet")

# %% [markdown]
# # Evaluation

# %%
df
# Out:
#                                 dataset              table_name_a  \
# 0                     000000_tables.sql                   address
# 1                     000000_tables.sql          customer_address
# 2                     000000_tables.sql          customer_address
# 3                     000000_tables.sql                    brands
# 4                     000000_tables.sql             category_item
# ...                                 ...                       ...
# 105230  695776_V1.0__Initial_Schema.sql             hr_attendance
# 105231  695776_V1.0__Initial_Schema.sql  hr_timesheet_sheet_sheet
# 105232  695776_V1.0__Initial_Schema.sql  hr_timesheet_sheet_sheet
# 105233  695776_V1.0__Initial_Schema.sql  hr_timesheet_sheet_sheet
# 105234  695776_V1.0__Initial_Schema.sql  hr_timesheet_sheet_sheet
#
#          table_name_b                                          columns_a  \
# 0               state  [id, uuid, flat_buil_number, locality, city, p...
# 1            customer                      [id, customer_id, address_id]
# 2             address                      [id, customer_id, address_id]
# 3             address  [id, uuid, brand_name, customer_rating, number...
# 4                item                         [id, item_id, category_id]
# ...               ...                                                ...
# 105230      res_users  [id, create_uid, create_date, write_date, writ...
# 105231      res_users  [id, create_uid, create_date, write_date, writ...
# 105232  hr_department  [id, create_uid, create_date, write_date, writ...
# 105233    hr_employee  [id, create_uid, create_date, write_date, writ...
# 105234      res_users  [id, create_uid, create_date, write_date, writ...
#
#                                                 columns_b primary_keys_a  \
# 0                                  [id, uuid, state_name]             id
# 1       [id, uuid, firstname, lastname, email, contact...             id
# 2       [id, uuid, flat_buil_number, locality, city, p...             id
# 3       [id, uuid, flat_buil_number, locality, city, p...             id
# 4                            [id, uuid, item_name, price]             id
# ...                                                   ...            ...
# 105230  [id, active, login, password, company_id, part...             id
# 105231  [id, active, login, password, company_id, part...             id
# 105232  [id, create_uid, create_date, write_date, writ...             id
# 105233  [id, create_uid, create_date, write_date, writ...             id
# 105234  [id, active, login, password, company_id, part...             id
#
#        primary_keys_b          key_a key_b
# 0                  id       state_id    id
# 1                  id    customer_id    id
# 2                  id     address_id    id
# 3                  id     address_id    id
# 4                  id        item_id    id
# ...               ...            ...   ...
# 105230             id      write_uid    id
# 105231             id     create_uid    id
# 105232             id  department_id    id
# 105233             id    employee_id    id
# 105234             id      write_uid    id
#
# [105235 rows x 9 columns]

# %%
subset1 = df["key_a"]==df["key_b"]
print(f"foreign_key == primary_key: {subset1.sum()}/{df['key_a'].count()}")
df[subset1].head()
# Out:
# foreign_key == primary_key: 40348/105235
#               dataset  table_name_a table_name_b          columns_a  \
# 12  000009_schema.sql      dept_emp    employees  [emp_no, dept_no]
# 13  000009_schema.sql      dept_emp  departments  [emp_no, dept_no]
# 14  000009_schema.sql  dept_manager  departments  [dept_no, emp_no]
# 15  000009_schema.sql  dept_manager    employees  [dept_no, emp_no]
# 16  000009_schema.sql      salaries    employees   [emp_no, salary]
#
#                                             columns_b primary_keys_a  \
# 12  [emp_no, emp_title_id, birth_date, first_name,...
# 13                               [dept_no, dept_name]
# 14                               [dept_no, dept_name]
# 15  [emp_no, emp_title_id, birth_date, first_name,...
# 16  [emp_no, emp_title_id, birth_date, first_name,...
#
#    primary_keys_b    key_a    key_b  distance
# 12                  emp_no   emp_no         0
# 13                 dept_no  dept_no         0
# 14                 dept_no  dept_no         0
# 15                  emp_no   emp_no         0
# 16                  emp_no   emp_no         0

# %%
subset2 = df["key_a"]==df["table_name_b"]+df["key_b"]
print(f"foreign_key == table_id+primary_key: {subset2.sum()}/{df['key_a'].count()}")
df[subset2].head()
# Out:
# foreign_key == table_id+primary_key: 1905/105235
#                     dataset  table_name_a table_name_b  \
# 173   000260_event_room.ddl    event_room        event
# 174   000260_event_room.ddl    event_room         room
# 325  001075_database.pg.sql  accountroles      account
# 326  001075_database.pg.sql       remarks    workspace
# 327  001075_database.pg.sql    subproblem    workspace
#
#                                 columns_a  \
# 173           [eventid, roomid, position]
# 174           [eventid, roomid, position]
# 325                     [accountid, role]
# 326                [workspaceid, remarks]
# 327  [id, workspaceid, definition, title]
#
#                                           columns_b primary_keys_a  \
# 173                                              []        eventid
# 174                                              []        eventid
# 325   [id, username, firstname, lastname, password]
# 326  [id, owner, title, problem, defaultscenarioid]    workspaceid
# 327  [id, owner, title, problem, defaultscenarioid]             id
#
#     primary_keys_b        key_a key_b  distance
# 173                     eventid    id         5
# 174                      roomid    id         4
# 325             id    accountid    id         7
# 326             id  workspaceid    id         9
# 327             id  workspaceid    id         9

# %%
subset3 = df["key_a"]==df["table_name_b"]+"_"+df["key_b"]
print(f"foreign_key == table_id_primary_key: {subset3.sum()}/{df['key_a'].count()}")
df[subset3].head()
# Out:
# foreign_key == table_id_primary_key: 12385/105235
#              dataset      table_name_a table_name_b  \
# 0  000000_tables.sql           address        state
# 1  000000_tables.sql  customer_address     customer
# 2  000000_tables.sql  customer_address      address
# 3  000000_tables.sql            brands      address
# 4  000000_tables.sql     category_item         item
#
#                                            columns_a  \
# 0  [id, uuid, flat_buil_number, locality, city, p...
# 1                      [id, customer_id, address_id]
# 2                      [id, customer_id, address_id]
# 3  [id, uuid, brand_name, customer_rating, number...
# 4                         [id, item_id, category_id]
#
#                                            columns_b primary_keys_a  \
# 0                             [id, uuid, state_name]             id
# 1  [id, uuid, firstname, lastname, email, contact...             id
# 2  [id, uuid, flat_buil_number, locality, city, p...             id
# 3  [id, uuid, flat_buil_number, locality, city, p...             id
# 4                       [id, uuid, item_name, price]             id
#
#   primary_keys_b        key_a key_b
# 0             id     state_id    id
# 1             id  customer_id    id
# 2             id   address_id    id
# 3             id   address_id    id
# 4             id      item_id    id

# %%
subsetnot123 = ~(subset1 | subset2 | subset3)
print(f"foreign_key != table_id or primary_key: {subsetnot123.sum()}/{df['key_a'].count()}")
df[subsetnot123].head()
# Out:
# foreign_key != table_id or primary_key: 50597/105235
#                                 dataset     table_name_a table_name_b  \
# 7                     000000_tables.sql      brands_item       brands
# 9                     000000_tables.sql  brands_category       brands
# 11                    000009_schema.sql        employees       titles
# 17                        000036_12.sql        dashboard        users
# 18  000044_V21__rolle_recht__create.sql      rolle_recht        rolle
#
#                                             columns_a  \
# 7                             [id, item_id, brand_id]
# 9                         [id, brand_id, category_id]
# 11  [emp_no, emp_title_id, birth_date, first_name,...
# 17  [id, name, description, scope, groups, owner_i...
# 18       [rolle_recht_rolle_id, rolle_recht_recht_id]
#
#                                             columns_b primary_keys_a  \
# 7   [id, uuid, brand_name, customer_rating, number...             id
# 9   [id, uuid, brand_name, customer_rating, number...             id
# 11                                  [title_id, title]
# 17                                                 []             id
# 18                                                 []
#
#    primary_keys_b                 key_a     key_b  distance
# 7              id              brand_id        id         6
# 9              id              brand_id        id         6
# 11                         emp_title_id  title_id         4
# 17                             owner_id        id         6
# 18                 rolle_recht_rolle_id  rolle_id        12
